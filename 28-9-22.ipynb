# %%
i=3
if(i%3==0):
  print("fizz")
  if(i%5==0):
    print("buzz")
else:
      print("fizzbuzz")
# Out:
# fizz

# %%
n=15
if n%3==0 and n%5==0:
  print("fizzbuzz")
elif n%3==0:
    print("fizz")
else:
      print("buzz")
# Out:
# fizzbuzz

# %%
def table(n):
  n=int(input('write any no.'))
  for i in range(1,11):
    print(i*n)

# %%
table(n)
# Out:
# write any no.56
# 56
# 112
# 168
# 224
# 280
# 336
# 392
# 448
# 504
# 560
